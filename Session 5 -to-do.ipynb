# %%
#Create URL to JSON file (alternatively this can be a filepath)
url = 'https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json'

# Load library
import pandas as pd

# Load the first sheet of the JSON file into a data frame
df = pd.read_json(url, orient='columns')
# View the first ten rows
df.head(10)
# Out:
#     category            datetime  integer
# 0          0 2015-01-01 00:00:00        5
# 1          0 2015-01-01 00:00:01        5
# 10         0 2015-01-01 00:00:10        5
# 11         0 2015-01-01 00:00:11        5
# 12         0 2015-01-01 00:00:12        8
# 13         0 2015-01-01 00:00:13        9
# 14         0 2015-01-01 00:00:14        8
# 15         0 2015-01-01 00:00:15        8
# 16         0 2015-01-01 00:00:16        2
# 17         0 2015-01-01 00:00:17        1

# %%
#2. read the HTML file as given below

url1 = "http://vincentarelbundock.github.io/Rdatasets/datasets.html"

htmll = pd.read_html(url1)

htmll[0][0:5].iloc[:,:]
# Out:
#                                                 0          1     \
# 0  Package Item Title Rows Cols CSV Doc boot acme...    Package
# 1                                            Package       Item
# 2                                               boot       acme
# 3                                               boot       aids
# 4                                               boot  aircondit
#
#                                            2      3     4     5    6    7     \
# 0                                          Item  Title  Rows  Cols  CSV  Doc
# 1                                         Title   Rows  Cols   CSV  Doc  NaN
# 2                        Monthly Excess Returns     60     3   CSV  DOC  NaN
# 3  Delay in AIDS Reporting in England and Wales    570     6   CSV  DOC  NaN
# 4        Failures of Air-conditioning Equipment     12     1   CSV  DOC  NaN
#
#    8     9     ...   8027  8028  8029   8030       8031  \
# 0  boot  acme  ...   11.0   CSV   DOC  Zelig  Zelig.url
# 1   NaN   NaN  ...    NaN   NaN   NaN    NaN        NaN
# 2   NaN   NaN  ...    NaN   NaN   NaN    NaN        NaN
# 3   NaN   NaN  ...    NaN   NaN   NaN    NaN        NaN
# 4   NaN   NaN  ...    NaN   NaN   NaN    NaN        NaN
#
#                        8032  8033 8034  8035  8036
# 0  Table of links for Zelig  49.0  2.0   CSV   DOC
# 1                       NaN   NaN  NaN   NaN   NaN
# 2                       NaN   NaN  NaN   NaN   NaN
# 3                       NaN   NaN  NaN   NaN   NaN
# 4                       NaN   NaN  NaN   NaN   NaN
#
# [5 rows x 8037 columns]
